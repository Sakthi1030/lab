# %%
import pandas as pd

# %%
df=pd.read_csv("U.S. Home Sales 1963-2016.csv",sep=',')
df
# Out:
#        per_idx    per_name  cat_idx cat_code  \
# 0            1  1963-01-01        1     SOLD
# 1            1  1963-01-01        1     SOLD
# 2            1  1963-01-01        1     SOLD
# 3            1  1963-01-01        1     SOLD
# 4            1  1963-01-01        1     SOLD
# ...        ...         ...      ...      ...
# 20399      646  2016-10-01        3  FORSALE
# 20400      646  2016-10-01        3  FORSALE
# 20401      646  2016-10-01        3  FORSALE
# 20402      646  2016-10-01        3  FORSALE
# 20403      646  2016-10-01        3  FORSALE
#
#                                 cat_desc  cat_indent  dt_idx dt_code  \
# 0          New Single-family Houses Sold           0       5  MEDIAN
# 1          New Single-family Houses Sold           0       2  NOTSTD
# 2          New Single-family Houses Sold           0       3  UNDERC
# 3          New Single-family Houses Sold           0       4  COMPED
# 4          New Single-family Houses Sold           0       1   TOTAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20404 entries, 0 to 20403
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   per_idx     20404 non-null  int64
#  1   per_name    20404 non-null  object
#  2   cat_idx     20404 non-null  int64
#  3   cat_code    20404 non-null  object
#  4   cat_desc    20404 non-null  object
#  5   cat_indent  20404 non-null  int64
#  6   dt_idx      20404 non-null  int64
#  7   dt_code     15354 non-null  object
#  8   dt_desc     15354 non-null  object
#  9   dt_unit     15354 non-null  object
#  10  et_idx      20404 non-null  int64
#  11  et_code     5050 non-null   object
#  12  et_desc     5050 non-null   object
#  13  et_unit     5050 non-null   object
#  14  geo_idx     20404 non-null  int64
#  15  geo_code    20404 non-null  object
#  16  geo_desc    20404 non-null  object
#  17  is_adj      20404 non-null  int64
#  18  val         18610 non-null  float64
# ...

# %%
a=df.shape
b=df.head(2)
c=df.tail(2)

# %%
df=df.head(10)

# %%
df=df[(df['cat_code']=="SOLD")&(df['dt_code']=="MEDIAN")]
df
# Out:
#    per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0        1  1963-01-01        1     SOLD  New Single-family Houses Sold
#
#    cat_indent  dt_idx dt_code             dt_desc dt_unit  et_idx et_code  \
# 0           0       5  MEDIAN  Median Sales Price     DOL       0     NaN
#
#   et_desc et_unit  geo_idx geo_code       geo_desc  is_adj      val  serialid
# 0     NaN     NaN        1       US  United States       0  17200.0         1

# %%
df_underc = df[df['dt_code']=='UNDERC']

# %%
df_underc
# Out:
# Empty DataFrame
# Columns: [per_idx, per_name, cat_idx, cat_code, cat_desc, cat_indent, dt_idx, dt_code, dt_desc, dt_unit, et_idx, et_code, et_desc, et_unit, geo_idx, geo_code, geo_desc, is_adj, val, serialid]
# Index: []

# %%
df1=df[pd.notnull(df['dt_code'])]

# %%
df1
# Out:
#    per_idx    per_name  cat_idx cat_code                       cat_desc  \
# 0        1  1963-01-01        1     SOLD  New Single-family Houses Sold
#
#    cat_indent  dt_idx dt_code             dt_desc dt_unit  et_idx et_code  \
# 0           0       5  MEDIAN  Median Sales Price     DOL       0     NaN
#
#   et_desc et_unit  geo_idx geo_code       geo_desc  is_adj      val  serialid
# 0     NaN     NaN        1       US  United States       0  17200.0         1

# %%
df_comped = df[df['dt_code']=='COMPED']
df_comped
# Out:
# Empty DataFrame
# Columns: [per_idx, per_name, cat_idx, cat_code, cat_desc, cat_indent, dt_idx, dt_code, dt_desc, dt_unit, et_idx, et_code, et_desc, et_unit, geo_idx, geo_code, geo_desc, is_adj, val, serialid]
# Index: []

# %%
DF_AVERAGE = df[df['dt_code']=='AVERAGE']
DF_AVERAGE
# Out:
# Empty DataFrame
# Columns: [per_idx, per_name, cat_idx, cat_code, cat_desc, cat_indent, dt_idx, dt_code, dt_desc, dt_unit, et_idx, et_code, et_desc, et_unit, geo_idx, geo_code, geo_desc, is_adj, val, serialid]
# Index: []
