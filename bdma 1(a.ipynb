# %%
import pandas as pd
df=pd.read_csv('survey_results_public - survey_results_public.csv',index_col='Respondent')
schema_df=pd.read_csv('survey_results_schema - survey_results_schema.csv',index_col='Column')
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',25)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
Filt=(df['Country']=='India')
india_df=df.loc[Filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country         Student  \
# Respondent
# 8           Not employed, but looking for work   India             NaN
# 10                          Employed full-time   India              No
# ...

# %%
india_df.to_csv('modified.csv')
india_df.to_csv('modified.tsv',sep='\t')

# %%
pip install xlwt openpyxl xlrd
# Out:
# ...
#                                               0.0/100.0 kB ? eta -:--:--
#      -----------                             30.7/100.0 kB 1.4 MB/s eta 0:00:01
#      ------------------------------------ 100.0/100.0 kB 954.7 kB/s eta 0:00:00
# ...
#                                               0.0/96.5 kB ? eta -:--:--
#      ---------------------------------------- 96.5/96.5 kB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
india_df.to_excel('modified.xlsx')
test=pd.read_excel('modified.xlsx',index_col='Respondent')

# %%
india_df.to_json('modified.json',orient='records',lines=True)
test=pd.read_json('modified.json',orient='records',lines=True)
test.head(5)
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# 1                  Employed full-time   India              No
# 2  Not employed, but looking for work   India  Yes, full-time
#
#                                              EdLevel  \
# 0         Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
pip install pymysql
# Out:
# ...
#                                               0.0/44.8 kB ? eta -:--:--
#      ---------------------------              30.7/44.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 44.8/44.8 kB 556.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
engine=sqlalchemy.create_engine('mysql+pymysql://root:12345@localhost:3306/sakila')
df=pd.read_sql_table('actor',engine)
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
india_df.to_sql('Indiavikas',engine)
# Out:
# C:\Users\Sandi\AppData\Local\Temp\ipykernel_10384\1602737842.py:1: UserWarning:
#
# The provided table name 'Indiavikas' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 3
